# %% [markdown]
# ## DA-AG-007 ASSIGNMENT
#
# ---

# %% [markdown]
# 1.What is hypothesis testing in statistics ?
#   - Hypothesis testing is a statistical method used to make decisions or draw conclusions about a population based on sample data. It helps determine whether the evidence supports a paricular assumption or claim.
#
#       - Null Hypothesis (Ho): The default assumption, usually stating that there is no effect or no difference.
#            - example: The average website visits are 50 per day.
#
#       - Alternative Hypothesis(H1): The competing claim, suggesting there is an effect or difference.
#            - example: The average website visits are not 50 per day.
#
#       - Significance Level(α): The threshold for deciding whether to reject Ho, often set at 005%.
#
#       - p-value : The probability of observing the data if Ho is true. A small p-value (<α) suggests rejecting Ho.
#
#       - Test Statistic: A calcutated value used to compare against critical values to decide whether to reject Ho.

# %% [markdown]
# 2.What is the null hypothesis, and how does it differ from the alternative hypothesis?
#   - Null Hypothesis (Ho)
#        - Definition : The null hypothesis assumes no effect, no difference, or no relationship between variables.
#        - Purpose : It acts the default or baseline assumption in statistical testing.
#        - Form : Usually expressed with equality( Ho : - Form: Usually expressed with equality (H₀:u =10).
#        - Example : There is no difference in exam scores between students who study with flashcards and those who don't.
#
#
#   - Alternative Hypothesis (H1 : Ha)
#       - Definition : The alternative hypothesis suggets there is an effect, a difference, or a relationship.
#       - Purpose : It represents what the reseacher aims to support with evidence.
#       - Form : Often expressed with inequality
#       - Example : Students who study with flashcards score higher on exams than those who don't.

# %% [markdown]
# 3.Explain the significance level in hypothesis testing and its role in deciding the outcome of a test.
#   - The significance Level is a threshold set by the researcher before conducting a statistical test. It plays a crucial role in deciding whether to reject the null hypothesis.
#
#   - Definition : The probability of rejecting null hypothesis when it is actually true.
#   - Common Values : 5%, 1%, 10%.
#   - Interpretation : A significance level of 0.05 means you accept a 5% chance of wrongly rejecting the null hypothesis.

# %% [markdown]
# 4.What are Type 1 and Type @ errors ? Give examples of each ?
#   - Type 1 Error (False Positive)
#      - Definition : Rejecting the null hypothesis when it is actually true.
#      - Symbol : alpha (significance level)
#      - Meaning : You conclude there is an effect when in reality there isn't.
#      - Example
#           - A medical test says a patient has COVID-19 when they actually don't.
#           - In research : Claiming a new teaching method imporves scores when, in fact, it doesn't.
#
#
#  - Type 2 Error (False Negative)
#     - Definition : Failing to reject the null hypothesis when the alternative hypothesis is actually true.
#     - Symbol : beta
#     - Meaning : You conclude there is no effect when in reality there is
#     - Example
#          - A medical test says a patient does not have COVID-19 when they actually do.
#          - In research : Concluding a new drug has no effect when it actually works.

# %% [markdown]
# 5.What is the difference between a Z-test and a T-test? Explain when to use each.
#   - Z - Test
#
#     - Definition :  A statistical test based on the standard normal distribution (Z-distribution)
#     - When to use
#       - Large sample size (n ≥ 30).
#       - Population variance is known.
#
#     - Applications
#       - Comparing sample mean to population mean.
#       - Comparing means of two large samples
#       - Example : Testing whether the average height of 1000 students differ form the national average, when the population standard deviationo is known.
#
#   - T - Test
#      - Definition : A statistical test based on the t-distribution, which accounts for more variability in small samples.
#      - When to use
#        - Small sample size (n < 30 )
#        - Population variance is unknown
#      - Applications
#        - Comparing sample mean to population mean.
#        - Comparing means of two small samples.
#        - Example : Testing whether the average score of 15 student in a class differs from the expected average, when population variance is unknown.

# %% [markdown]
# 6.Write a Python program to generate a binomial distribution with n = 10 and p = 0.5, then plot its histogram.
#   -

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
p = 0.5
size = 1000

data = np.random.binomial(n, p, size)

plt.hist(data, bins = range(n+2), edgecolor = 'black', alpha = 0.75)
plt.title("Binomial Distribution")
plt.xlabel("Number of Successes")
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 7.Implement hypothesis testing using Z-statistics for a sample dataset in Python. Show the Python code and interpret the results.
# sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
# 50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
# 50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
# 50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# %%
import numpy as np
from scipy.stats import norm

sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

mu_0 = 50

sigma = 0.5

alpha = 0.05

sample_mean = np.mean(sample_data)
n = len(sample_data)

z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(n))

p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print("Sample Mean : ", sample_mean)
print("Z-statistic : ", z_stat)
print("p-value :", p_value)


if p_value < alpha:
    print("Reject the null hypothesis : The sample mean is significantly different from 50")
else:
    print("Fail to reject the null hypothesis : No significant difference from 50")
# Out:
# Sample Mean :  50.08888888888889
# Z-statistic :  1.0666666666666629
# p-value : 0.2861223843910199
# Fail to reject the null hypothesis : No significant difference from 50

# %% [markdown]
# 8.Write a Python script to simulate data from a normal distribution and calculate the 95% confidence interval for its mean. Plot the data using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

np.random.seed(42)
mu, sigma = 50, 5
n = 100

data = np.random.normal(mu, sigma, n)
sample_std = np.std(data, ddof = 1)
se = sample_std / np.sqrt(n)

confidence = 0.95
z_critical = stats.norm.ppf(1 -(1-confidence)/2)

margin_of_error = z_critical * se
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

print("sample Mean : ", sample_mean)
print("95% Confidence Interval : ({:.2f},{:.2f})".format(ci_lower, ci_upper))

plt.hist(data, bins = 15, edgecolor = 'black', alpha = 0.7)
plt.axvline(sample_mean, color = 'red', linestyle = 'dashed', linewidth= 2, label = f"Mean = {sample_mean:.2f}" )
plt.axvline(ci_lower, color = "green", linestyle = "dashed", linewidth = 2, label = f"Lower CI = {ci_lower:.2f}")
plt.axvline(ci_upper, color = "green", linestyle = "dashed", linewidth = 2, label = f"Upper CI = {ci_upper:.2f}")
plt.title("Normal Distribution simulation with 95% CI")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# sample Mean :  50.08888888888889
# 95% Confidence Interval : (49.20,50.98)

# %% [markdown]
# 9.Write a Python function to calculate the Z-scores from a dataset and visualize the standardized data using a histogram. Explain what the Z-scores represent in terms of standard deviations from the mean.

# %%
import numpy as np
import matplotlib.pyplot as plt

def z_score_standardization(data):
    mean = np.mean(data)
    std = np.std(data, ddof =1)
    z_scores = (data - mean) / std

    print("Mean of data:", mean)
    print("Standard Deviation of data:", std)
    print("First 5 Z-scores:", z_scores[:5])

    plt.hist(z_scores, bins = 15, edgecolor = "black",alpha = 0.7)
    plt.title("Histogram of Z-scores (Standardized Data)")
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.axvline(0, color = "red", linestyle = "dashed", linewidth = 2, label = "Mean = 0")
    plt.legend()
    plt.show()

    return z_scores
data = np.random.normal(50, 5, 100)
z_scores = z_score_standardization(data)
# Out:
# Mean of data: 50.111522935249624
# Standard Deviation of data: 4.7683448309155185
# First 5 Z-scores: [-1.5075203  -0.46446925 -0.38275242 -0.8646416  -0.19250946]

# %% [markdown]
# 9.Write a Python funcation to calculate the Z-scores from a dataset and visualize the standardized data using a histogram. Explain what the z-scores represent in terms of standard deviations from the mean.
#   -

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
  mean = np.mean(data)
  std = np.std(data, ddof = 1)

  z_scores = (data - mean) / std

  print("Mean of data:", mean)
  print("Standard Deviation of data:", std)
  print("First 5 Z-scores:", z_scores[:5])

  plt.hist(z_scores, bins = 15, edgecolor = "black", alpha = 0.7)
  plt.title("Histogram of Z-scores (Standardized Data)")
  plt.xlabel("Z-score")
  plt.ylabel("Frequency")
  plt.axvline(0, color = "red", linestyle = "dashed", linewidth = 2, label = "Mean (z = 0)")

  return z_scores

data = np.random.normal(50, 5, 100)
z_scores = calculate_z_scores(data)
# Out:
# Mean of data: 49.71997764744829
# Standard Deviation of data: 5.318651609494473
# First 5 Z-scores: [-1.44625302 -0.51081608  0.05757866  0.09681501 -0.37045198]
