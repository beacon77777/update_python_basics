# %% [markdown]
# # Python Oops Assignment
#
# ---

# %% [markdown]
# 1.What is Object-Oriented Programming(Oops)?
#   - Object-Oriented Programming (Oops) is programming paradigm that organizes software design around objects rather than funcations or logic.
#        - An object is bundle of attributes and methods.
#        - OOP makes programs more modular, reusable, and easier to maintain.

# %% [markdown]
# 2.What is a class in Oop ?
#   - A class is like a blueprint or template in Object-Oriented Programming.
#       - Class -> Recipe for making a cake.
#       - Object-> The actual cake baked using that recipe.

# %% [markdown]
# 3.What is an object in OOP ?
#   - An object in OOp is a real world entity created from a class.
#      - It is an instance of a class.
#      - Objects hold data (attributes) and can perform actions(methods) defined by the class.

# %% [markdown]
# 4.What is the difference between abstraction and encapsulation ?
#   - Abstraction
#      - Hides implementation details and shows only essential features to the user.  {definition}
#
#      - To reduce complexity by exposing only relevant details. {purpose}
#      - focuses on what an object does. {Focus}
#      - Achieved using abstract classes and interfaces.{Implementation in python}
#      - Driving a car: you only know how to use the steering wheel and pedals,not the engine machanics.{Analogy}
#
#   - Encapsulation ->
#      - Bundles data (variables) and methods(funcation) into a single unit (class) and restricts direct access.{definitation}
#      - To protect data and ensure controlled access.{purpose}
#      - Implementation level (focuses on how data is stored and accessed.) {focus}
#      - Achieved using private/protected attributes (_variable,__variable) and getter/setter methods.{implementation in python}
#      - Car's engine is encapsulatation under the hood; you can't directly tamper with it,only use provided controls. {Analogy}

# %% [markdown]
# 5.What are dunder methods in Python ?
#   - Dunder methods in python are methods whose names start and end with double underscores "____like_this_ ___ ".
#   They let you customize how your objects behave with built-in operations such as prining, arithmetic,comparisions.
#
#   examples:-
#   - __init__ : Constructor, run when an object is created.
#   - __str__  : Defines user friendly representation (print(obj))
#   - __repr__ : Defines developer- friendly representation (seen in interactive console.)
#   - __add__  : Enables operator overloading(obj1 + obj2).
#   - __len__  : Defines behavior for len(obj).
#   - __call__ : Makes an object callable like a funcation.

# %% [markdown]
# 6.Explain the concept of inheritance in Oop .
#   - Inheritance means one class (child) can use the properties and methods of another class(parent)

# %%
class animal:
  def speak(self):
    return "This animal makes a sound"

class dog(animal):
  def speak(self):
    return "Bhaoooohhh"


dog = dog()
print(dog.speak())
# Out:
# Bhaoooohhh

# %% [markdown]
# 7.What is polymorphism in Oop ?
#   - Polymorphism in object oriented Programming (Oop) mean "many forms".
#   - It allows the same funcation or method name to behave differently depending on the object that calls it.

# %%
class bird:
  def fly(self):
    return "Birds can fly"

class sparrow(bird):
  def fly(self):
    return "Sparrows can fly"

class penguin(bird):
  def fly(self):
    return "Penguins cannot fly"

birds = [sparrow(),penguin()]
for bird in birds:
  print(bird.fly())
# Out:
# Sparrows can fly
# Penguins cannot fly

# %% [markdown]
# 8.How is encapsulation achieved in Python ?
#   - Encapsulation means hiding the internal details of an object and restricting direct to its data.
#
#
#    **important note : Data security + Controlled access.

# %%
class bank_account:
  def __init__(self,owner,balance = 0):
    self.owner = owner
    self.__balance = balance

  def get_balance(self):
    return self.__balance

  def deposit(self,amount):
    if amount > 0:
      self.__balance += amount
    else:
      print("Insufficient balance")
account =  bank_account("Rahul", 1000)
print(account.get_balance())
account.deposit(500)
print(account.get_balance())
# Out:
# 1000
# 1500

# %% [markdown]
# 9.What is a constructor in Python ?
#   - A constructor in Python is a special method used to initialize objects when they are created from a class.
#     - It sets up the initial state of the object (assigns values to attributes)
#     - In python , the constructor method is always named __init__.

# %% [markdown]
# 10.What are class and static methods in Python ?
#  - Class Methods
#
#    - Defined using the @classmethod decorator.
#    - They take cls (class itself) as the first argument instead of self.
#    - Used when you want to work with the class as a whole, not individual objects.
#    - Often used for factory methods (creating objects indifferen ways).
#
#  - Static Methods
#
#    - Defined using the @staticmethod decorator.
#    - They don't take self or cls as the first argument.
#    - Behave like normal funcations, but live inside the class for logical grouping.
#    - Used when the method doesn't need access to class or instance data.

# %% [markdown]
# 11.What is method overloading in Python ?
#    - Method overloading means defining multiple methods with the same name but different parameters so they can perform different tasks depending on the arguments passed.
#
#    - In many languages like java or C++, true method overloading is supported directly.
#    - But in Python, method overloading is not natively supported - instead , python uses default uses default arguments and variable - length arguments (*args,**kwargs) to achieve similar behaviour.

# %% [markdown]
# 12.What is method overriding in OOP ?
#    - Method overriding happens when a child class provides its own implementation of a method that is already defined in the parent class.
#        - The method name and parameters remain the same.
#        - The child class's version replace(overrides) the parent's version when called on the child object.
#        - **impor : same method name , different behavior in child class.

# %% [markdown]
# 13.What is a property decorator in python ?
#    - A property decorator (@property) in python is used to define methods that can be accessed like attributes.
#       - It allow you to control access to private variables while keeping a clean syntax.
#       - Instead of calling a method like obj.get_value(), you can simply use obj.value.
#       -**impro :- It turns a method into a "read-only attribute".

# %% [markdown]
# 14.Why is polymorphism important in OOP ?
#    - Polymorphism = "same interface, different implementations."
#    - It's one of the four pillars of OOP.
#
# Flexibility and Extensibility
#
#    - You can write code that works with different types of objects without changing the logic.
#    - example :- A fly() method works for sparrow and penguin, but each has its own behavior.
#
# Code Reusability
#
#   - Common interfaces mean you don't need to rewrite code for eachd new class.
#   - example :- A funcation that calls speak() can work for Dog,Cat or without modification.
#
# Simplifies Maintenance
#
#   - Changes in child classes don't break parent class code.
#   - You can add new classes with their own behavior without touching existing code.
#
# Supports Dynamic Behavior (runtime Polymorphism)
#   - At runtime, Python decides which method to execute based on the object type.
#   - This makes systems more adaptable and scalable.

# %% [markdown]
# 15.What is an abstract class in Python ?
#    - An abstract class in Python is a class that can not be instantiated directly.
#
#       - It serves as a blueprint for other classes.
#       - It can define abstract methods
#       - Child classes must implement these abstract method to become concrete(usable).
#       - **impor : Abstract class = " Template class with incomplete methods that subclasses must complete."

# %% [markdown]
# 16.What are the advantages of OOP ?
#    - The main advantages of Object-oriented programming (OOP) are code reusability,modularity,scalability,easier maintenance, and real world modeling.
#    - It helps developers build flexible, organized, and secure applications.
#
#
# Modularity
#   - Code is divided into classes and objects,making it easier to understand and manage.
#   - Each class handles a specific responsibility, reducing complexity.
#
# Reusability
#   - Through inheritance, existing code can be reused in new applications.
#   - Saves time and effort by avoiding duplication
#
# Scalability and Extensibility
#   - OOP systems can be easily extended by adding new classes or methods.
#   - Polymorphism allows new behaviors without changing existing code
#
# Maintainability
#
#   - Encapsulation ensures that changes in one part of the code don't break other parts.
#   - Easier debugging and updating since classes are self-contained.
#
# Abstraction
#
#   - Hides implementation details and shows only essential features.
#   - Make complex system easier to use and understand.
#
# Security
#   - Encapsulation protects data by restricting direct access.
#   - Only controlled method allow safe interaction with attributes.
#
# Real-World Modeling
#   - Classes and objects naturally represent real-world entities ( Car,BankAccount)
#   - Makes programs intuitive and closer to human thinking.

# %% [markdown]
# 17.What is the difference between a class variable and an instance variable ?
#
#     - Feature    	      Class Variable	                        Instance Variable
#       Definition	Shared by all objects of the class.	    Unique to each object of the class.
#       Scope     	Belongs to the class itself.	        Belongs to the object (instance).
#       Storage	    Stored in the class memory.	            Stored in the object’s memory.
#       Access	    Accessed using ClassName.variable 	    Accessed only through the object (object.variable).
#                       or object.variable.
#       Use Case	    For values common to all objects       	For values specific to each object (e.g., employee name).

# %% [markdown]
# 18.What is multiple inheritance in Python ?
#    - Multiple inheritance means a class can inherit feature (attributes and methods) from more than one parent class.
#
#    - **Import : A child class can have multiple parents.
#    - Python supports multiple inheritance directly.
#    - The child class gets access to all methods and attributes of its parent classes.
#    - if there are conflicts python uses the method resolution order (MRO) to decide which one to call.

# %% [markdown]
# 19.Explain the purpose of "__str__" and "__repr__" methods in python.
#
# __str__ :
#    - Called when you use print(obj) or str(obj).
#    - Its goal is to return a readable,human-friendly description of the object.
#
#
# __repr__
#   - Called when you use repr(obj) or just type the object in the python shell.
#   - Its goal is to return a precise, unambiguous description of the object, ideally one that could be used to recreate it.

# %% [markdown]
# 20.What is the significance of the 'super()' function in python ?
#    - The super() function in python is used to call methods from a parent (superclass) inside a child (subclass).
#    - It helps in reusing parent class code without explicitly naming the parent.
#    - It ensures proper method resolution order(MRO) in cases of multiple inheritance.
#    - **impor -> super() lets child classes access parent methods safely and cleanly.

# %% [markdown]
# 21.What is the significance of the __del__ method in python ?
#    -  The __del__ method in python is a destructor.
#       - It is automatically called when an object is about to be destroyed
#       - Its purpose is to clean up resources
#       - like closing files, releasing memory,disconnecting from databases.

# %% [markdown]
# 22.What is the difference between @staticmethod and @classmethod in python ?
#    - @staticmethod
#         - First Argument
#             - No default argument (behaves like a normal function inside class.)
#         - Access
#             - Can not access class variables or instance variables directly.
#         - Use Case
#             - Utility functions that logically belong to the class but don't depend on class or object state.
#
#   - @classmethod
#       - First Argument
#             - Takes cls as the first argument.
#         - Access
#             - Can access and modify class variables but not instance variables.
#         - Use Case
#             - Factory methods, counters, or operations that need to work with the class as a whole.

# %% [markdown]
# 23.How does polymorphism work in python with inheritance ?
#    - Polymorphism
#         - same method name, different behaviors depending on the object. when combined with inheritance,
#         - A parent class defines a method.
#         - Child classes override that method with their own implementation.
#         - At runtime, python decide which version to execute based on the object type. this is called runtime polymorphism.

# %% [markdown]
# 24.What is method chaining in python OOP ?
#    - Method chaining means calling multiple methods on the same object in a single line,because each method returns the object itself (self).
#    - **impor :- It makes code concise,readable and fluent.

# %% [markdown]
# 25.What is the purpose of the __call__ method in python ?
#    - The __call_ method in python allows an object to be called like a funcation/
#        - Normally, you call functions with func()
#        - If a class defines __call__ , then its objects can also be invoked using parentheses obj()
#        - This makes objects callable.
#        - **important -> __call__ turns an object into a function.

# %% [markdown]
# ## PRACTICAL QUESTIONS
#
# ---

# %% [markdown]
# 1.Create a parent class animal with a method speak() that print a generic message. Create a child class Dog that overrides the speak() method to print "Bark".

# %%
class animal:
  def speak(self):
    return "This animal makes a sound"

class dog(animal):
  def speak(self):
    return "Bhaoooohhh"


dog = dog()
print(dog.speak())
# Out:
# Bhaoooohhh

# %% [markdown]
# 2.Write a program to create an abstract class shape with a method area().Derive classes Circle and Rectangle from it and implement the area() method in both.
#   -

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Circle area:", circle.area())
print("Rectangle area:", rectangle.area())
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %% [markdown]
# 3.Implement a multi-level inheritance scenario where a class vehicle has an attribute type. Derive a class Car and further derive a class Electric Car that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, v_type):
        self.v_type = v_type

    def show_type(self):
        print(f"Vehicle type: {self.v_type}")

class Car(Vehicle):
    def __init__(self, v_type, brand):
        super().__init__(v_type)
        self.brand = brand

    def show_details(self):
        print(f"Car brand: {self.brand}, Type: {self.v_type}")

class ElectricCar(Car):
    def __init__(self, v_type, brand, battery_capacity):
        super().__init__(v_type, brand)
        self.battery_capacity = battery_capacity

    def show_info(self):
        print(f"Electric Car brand: {self.brand}, Type: {self.v_type}, Battery: {self.battery_capacity} kWh")

ecar = ElectricCar("Four-wheeler", "Tesla", 85)

ecar.show_type()
ecar.show_details()
ecar.show_info()
# Out:
# Vehicle type: Four-wheeler
# Car brand: Tesla, Type: Four-wheeler
# Electric Car brand: Tesla, Type: Four-wheeler, Battery: 85 kWh

# %% [markdown]
# 4.Demonstrate polymorphism by creating a base class bird with a method fly().Create two derived classes sparrow and penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Birds can fly in general.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead!")

birds = [Sparrow(), Penguin()]

for b in birds:
    b.fly()
# Out:
# Sparrow flies high in the sky!
# Penguins cannot fly, they swim instead!

# %% [markdown]
# 5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class SBI_BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance. ")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")
print("Your account in SBI Branch")
account = SBI_BankAccount(1000)
account.deposit(700)
account.withdraw(250)
account.check_balance()
# Out:
# Your account in SBI Branch
# Deposited: 700
# Withdrawn: 250
# Current Balance: 1450

# %% [markdown]
# 6.Demonstrate runtime polymorphism using a method play() in a base class Instrument Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
      print("Instrument is playing a sound.")
class Guitar(Instrument):
    def play(self):
      print("Strumming the guitar")
class Piano(Instrument):
    def play(self):
      print("Playing the piano")
instruments = [Guitar(), Piano()]
for inst in instruments:
    inst.play()
# Out:
# Strumming the guitar
# Playing the piano

# %% [markdown]
# 7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a, b):
        return a - b
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# 8.Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0
    def __init__(self, name):
        self.name = name
        Person.count += 1
    @classmethod
    def total_persons(cls):
        return cls.count
p1 = Person("Rahul")
p2 = Person("Alex")
p3 = Person("Thor")
print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# 9.Write a class Fraction with attributes numerator and denominator.Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)
print(f2)
# Out:
# 3/4
# 7/2

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    def __str__(self):
        return f"({self.x}, {self.y})"
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2
print(v3)
# Out:
# (6, 8)

# %% [markdown]
# 11.Create a class Person with attributes name and age.Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
p1 = Person("Rahul", 25)
p1.greet()
# Out:
# Hello, my name is Rahul and I am 25 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)
s1 = Student("Rahul", [88, 70, 95])
s2 = Student("Aditi", [70, 50, 60])
print(f"{s1.name}'s average grade: {s1.average_grade()}")
print(f"{s2.name}'s average grade: {s2.average_grade()}")
# Out:
# Rahul's average grade: 84.33333333333333
# Aditi's average grade: 60.0

# %% [markdown]
# 13.Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
rect = Rectangle()
rect.set_dimensions(10, 5)
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 50

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus
emp = Employee("Rahul", 40, 500)
mgr = Manager("Aditi", 45, 200, 5000)
print(f"{emp.name}'s Salary: ₹{emp.calculate_salary()}")
print(f"{mgr.name}'s Salary: ₹{mgr.calculate_salary()}")
# Out:
# Rahul's Salary: ₹20000
# Aditi's Salary: ₹14000

# %% [markdown]
# 15.Create a class Product with attributes name, price, and quantity.Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return self.price * self.quantity
p1 = Product("Laptop", 50000, 2)
p2 = Product("Phone", 20000, 3)
print(f"Total price of {p1.name}: ₹{p1.total_price()}")
print(f"Total price of {p2.name}: ₹{p2.total_price()}")
# Out:
# Total price of Laptop: ₹100000
# Total price of Phone: ₹60000

# %% [markdown]
# 16.Create a class Animal with an abstract method sound().Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        return "Moooo"
class Sheep(Animal):
    def sound(self):
        return "Baaaa"
animals = [Cow(), Sheep()]
for a in animals:
    print(a.sound())
# Out:
# Moooo
# Baaaa

# %% [markdown]
# 17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"
b1 = Book("The Alchemist", "Paulo Coelho", 1988)
b2 = Book("Wings of Fire", "A.P.J. Abdul Kalam", 1999)
print(b1.get_book_info())
print(b2.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988
# 'Wings of Fire' by A.P.J. Abdul Kalam, published in 1999

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
    def get_info(self):
        return f"House located at {self.address}, priced at ₹{self.price}"
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
    def get_info(self):
        return f"Mansion located at {self.address}, priced at ₹{self.price}, with {self.number_of_rooms} rooms"
h1 = House("Varanasi, UP", 5000000)
m1 = Mansion("Delhi, India", 25000000, 10)
print(h1.get_info())
print(m1.get_info())
# Out:
# House located at Varanasi, UP, priced at ₹5000000
# Mansion located at Delhi, India, priced at ₹25000000, with 10 rooms
