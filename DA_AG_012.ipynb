# %% [markdown]
# # Decision Tree Assignment

# %% [markdown]
# Question 1: What is a Decision Tree, and how does it work in the context of classification ?
# - Root Node : Represent the entire dataset and first decision point.
# - Internal Node : Each node corresponds to a test on a feature.
# - Branches : Outcomes of the test, leading to further nodes.
# - Leaf Nodes : Final classification labels.
#
#   - How it works in classification
#     - Splitting : The dataset is divided based on feature values using criteria like Gini Index, Information Gain, Chi-Squre.
#     - Decision Rules : At each node, the algorithm chooses the feature that best separates the classes.
#     - Recursive Partioning : This process continue until:
#       - All data points in a node belong to the same class.
#       - A stopping condition is reached.
#     - Prediction : For a new observation, the model traverses the tree from root to leaf, following the decision rules, and assigns the class at the leaf node.

# %% [markdown]
# Question 2.Explain the concepts of Gini Impurity and Entropy as impurity measures. How do they impact the split in Decision Tree /
#  - Gini impurity and Entropy are measures of how mixed the classes are within a node of a Decision Tree. Both guide the algorithm to choose splits that make child nodes purer, but they calculate impurity differently.
#
#  Key Concepts
#
#   - Gini Impurity
#
#     - Definition : Probability that a randomly chosen sample in a node would be misclassified if labeled according to the node's class distribution.
#     - Range : 0 to 0.5
#     - Interpretation : Lower Gini means purer nodes.
#
#   - Entropy
#     - Definition : Measures the amount of disorder or uncertainly in a node
#     - Range : 0 to 1
#     - Interpretation : Higher entropy means more mixed classes.
#
#
#  - Impact on Splitting
#    - Both aim to reduce impurity : The algorithm evaluates possible splits and chooses the one that maximizes purity imporvement.
#    - Information Gain : Measures reduction in entropy after a split.
#    - Gini Reduction : Measures reduction in Gini impurity after a split.
#    - Practical difference
#      - Gini often leads to similar splits as entropy but is computationally faster.
#      - Entropy can be more senstive when class distributiona are skewed.

# %% [markdown]
# Question 3 : What is the difference between Pre-Pruning in Decision Tree? Give one practical advantage of using each.
# - Pre-Pruning in Decision Trees
#   -Pre-pruning is a technique where the growth of the decision tree is halted early before it becomes too complex. Instead of letting the tree grow fully and then trimming it, pre-pruning sets conditions to stop splitting nodes.
#
# - Post-Pruning Advantage
#   - Produces a more accurate and generalized model since it evaluates the entire tree before deciding what to cut.
#   - Example: In medical diagnosis, post-pruning help avoid overfitting by trimming branches that only fit rare cases, leading to more relible predictions.

# %% [markdown]
# Question 4 : What is information Gain in Decision Trees, and Why is it important for choosing the best split ?
#
# Dataset Info:
# - Iris Dataset for classification tasks (sklearn.datasets.load_iris() or
# provided CSV).
# - Boston Housing Dataset for regression tasks
# (sklearn.datasets.load_boston() or provided CSV).
#
# - Iris Dataset
#   - Description : Contains measurements of 150 iris flowers across 3 species.
#   - Features : Sepal length, sepal width, petal length, petal width.
#   - Target : Species
#
# - Use Case:
#   - Train a decision tree to classify a flower species based on its measurements.
#   - Example : If petal length > threshold, predict Virginica.
#
# - Advantage:
#   - Simple, small dataset : great for learning and testing classification algorithms.
#
# - Boston Housing Dataset
#   - Description : Contains housing data for Boston suburbs
#   - Features : Crime rate, average number of rooms, property tax rate.
#   - Target : Median value of owner occupied homes.
# - Use case:
#   - Train a decision tree regressor to predict house based on neighborhood features.
#   - Example : If average rooms > threshold, predict higher median value.
# - Advantage:
#   - Real-world dataset : useful for understanding regression tasks and feature importance.
#
#
#   - Information Gain is a measure of how much a particular attribute reduces uncertainty in the dataset. it is crucial in decision trees because it helps identify the attribute that best separates the data into distinct classes, ensuring the most informative and efficient split.
#
#   - Information Gain quantifies the reduction in entropy after splitting a dataset based on a attribute.
#
#
#   - It is important for choosing the Best Split ?
#     - Guides Attribute selection : The attribute with the highest information Gain is chosen for splitting, ensuring the tree asks the most "informative" question first.
#
#     - Reduces Uncertainty : By maximizing information Gain, the tree reduces randomness in classification, leading to clearer decision boundaries.
#
#     - Improves Accuracy : Helps avoid unnecessary splits on weak attributes, which could lead to overfitting or poor generalization.
#
#     - Efficiency : Ensures fewer splits are needed to reach pure nodes, making the tree more compact and interpretable.

# %% [markdown]
# Question 5:What are some common real-world applications of Decision Trees, and what are their main advantages and limitations ?
# - Common real-world applications of decision trees.
#   - Finance and Risk Managment
#     - Used for credit scoring, loan approval, and fraud detection.
#     - Example : Banks classify applicants into 'approve' or 'reject' categories based on income, credit history, and employment status.
#
#   - Healthcare
#     - Applied in diagnosis and treatment planning.
#     - Example : Predicting whether a patient has a disease based on symptoms, test results, and medical history.
#
#   - Marketing and Customer analytics
#     - Helps in customer segmentation and predicting churn.
#     - Example: Retailers decide whether a customer is likely to respond to a promotion based on purchase history and demographics.
#
#   - Manufacturing and Quality control
#     - Used to identify defect causes and optimize processes.
#     - Example : Classifying products as "pass" or "fail" based on inspection data.
#
#   - Education
#     - Predicts student performance based on study habits, attendance, and prior grades.
#
# - Advantages of Decision Trees
#   - Interpretability : Easy to visualize and explain to non-technical stakeholders.
#   - Flexibility : Handles both classification and regression problem.
#   - Data Handling : Works with categorical and numerical features.
#   - No Assumptions : Doesn't require linear relationships or distribution assumptions.
#   - Feature Selection : Automatically selects the most informative attributes through measures like information Gain.

# %% [markdown]
# 6.Write a Python program to:
#   - Load the Iris Dataset
#   - Train a Decision Tree Classifier using the Gini criterion
#   - Print the model's accuracy and feature importances.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

clf = DecisionTreeClassifier(criterion="gini", random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy)

print("Feature Importances:")
for feature, importance in zip(iris.feature_names, clf.feature_importances_):
    print(f"{feature}: {importance:.4f}")
# Out:
# Model Accuracy: 1.0
# Feature Importances:
# sepal length (cm): 0.0000
# sepal width (cm): 0.0191
# petal length (cm): 0.8933
# petal width (cm): 0.0876

# %% [markdown]
# Question 7 :  Write a Python program to:
# - Load the Iris Dataset
# - Train a Decision Tree Classifier with max_depth=3 and compare its accuracy to a fully-grown tree.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

clf_shallow = DecisionTreeClassifier(max_depth=3, random_state=42)
clf_shallow.fit(X_train, y_train)
y_pred_shallow = clf_shallow.predict(X_test)
accuracy_shallow = accuracy_score(y_test, y_pred_shallow)

clf_full = DecisionTreeClassifier(random_state=42)
clf_full.fit(X_train, y_train)
y_pred_full = clf_full.predict(X_test)
accuracy_full = accuracy_score(y_test, y_pred_full)

print("Accuracy with max_depth=3:", accuracy_shallow)
print("Accuracy with fully-grown tree:", accuracy_full)
# Out:
# Accuracy with max_depth=3: 1.0
# Accuracy with fully-grown tree: 1.0

# %% [markdown]
# Question 8 : Write a Python program to:
# - Load the Boston housing dataset
# - Train a decision tree regressor
# - Print the mean squared error (MSE) and feature importances.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

housing = fetch_california_housing()
X = housing.data
y = housing.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)

print("Feature Importances:")
for feature, importance in zip(housing.feature_names, regressor.feature_importances_):
    print(f"{feature}: {importance:.4f}")
# Out:
# Mean Squared Error (MSE): 0.5280096503174904
# Feature Importances:
# MedInc: 0.5235
# HouseAge: 0.0521
# AveRooms: 0.0494
# AveBedrms: 0.0250
# Population: 0.0322
# AveOccup: 0.1390
# Latitude: 0.0900
# Longitude: 0.0888

# %% [markdown]
# 9.Write a Python program to:
#   - Load the iris dataset.
#   - Tune the Decision Tree's max_depth and min_sample_split using GridSearchCV.
#   - Print the best parameters and the resulting model accuracy.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
param_grid = {
    'max_depth': [2, 3, 4, 5, None],
    'min_samples_split': [2, 3, 4, 5, 10]
}

dt = DecisionTreeClassifier(random_state=42)

grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy with Best Parameters:", accuracy)
# Out:
# Best Parameters: {'max_depth': 4, 'min_samples_split': 10}
# Model Accuracy with Best Parameters: 1.0

# %% [markdown]
# 10. Imagine you are working as a data scientist for a healthcare company that wants to predict whether a patient has a certain disease. You have a large dataset with
# mixed data types and some missing values.
# - Explain the step-by-step process you would follow to:
#   - Handle the missing values
#   - Encode the categorical features
#   - Train a Decision Tree model
#   - Tune its hyperparameters
#   - Evaluate its performance
# And describe what business value this model could provide in the real-world
# setting.
#
# - Handle Missing Values
#   - Numeric Features
#     - Use imputation strategies like mean, median, or more advanced methods.
#
#   - Categorical Features
#     - Replace missing values with the most frequent category or introduce a special "Unknown" category.
#
#   - Business Notes
#     - Proper handling ensures no patient data is discarded unnecessarily, preserving valuable information.
#
# - Encode categorical features
#   - One-Hot encoding
#     - For nominal categories
#   - Ordinal Encoding
#     - For ordered categories
#   - Business Note
#     - Encoding allows the decision tree to process mixed data types effectively.
#
# - Train a Decision Tree Model
#   - Use DecisionTreeClassifier from scikit-learn.
#   - Train on the processed dataset.
#   - Decision trees naturally handle mixed data types and don't required feature scaling.
#
# - Tune Hyperparameters
#   - Use GridSearchCV or RandomizedsearchCV to tune parameters like:
#     - max_depth
#     - min_sample_split
#     - criterion
#   - Cross-validation ensures robust performance estimation
#
# - Evaluate Performance
#   - Metrics : Accuracy, Precision, Recall, F1-score, ROC-AUC
#   - Confusion Matrix : To understand misclassifications.
#   - Business Note : In healthcare, recall is often prioritized to avoid missing patients with the disease.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

dt = DecisionTreeClassifier(random_state=42)

param_grid = {'max_depth':[3,5,7,None], 'min_samples_split':[2,5,10]}
grid = GridSearchCV(dt, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)

best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)

print("Best Parameters:", grid.best_params_)
print("Model Performance:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_split': 10}
# Model Performance:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
